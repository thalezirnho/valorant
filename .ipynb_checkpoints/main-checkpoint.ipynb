# %%
# !pip install valorant
# Out:
# Collecting valorant
#   Downloading valorant-1.0.4-py3-none-any.whl (19 kB)
# Installing collected packages: valorant
# Successfully installed valorant-1.0.4

# %%
import os
import valorant

# %%
os.environ["VALPY-KEY"] = "RGAPI-88d6f215-b22d-4c82-ba97-d73924fc6db4"

# %%
KEY = os.environ["VALPY-KEY"]
client = valorant.Client(KEY, locale=None)

# %%
client.get_user_by_name(name="viikset#BR1", route="americas")
# Out:
# <class AccountDTO @gameName=viikset @handle=<valorant.caller.WebCaller object at 0x000001A118F8F7C0> @puuid=t6hgE7vM78zeB7VZqIF9BV4VC3xqSFyBQ_QaAK_l2xRSfxTqaTmh0Adqwc7V7QamAPszSWlTyDf2lg @tagLine=BR1>

# %%
client.get_match(id="c229a683-a205-4543-a174-522956e8b72d")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1228\78910206.py in <module>
# ----> 1 client.get_match(id="c229a683-a205-4543-a174-522956e8b72d")
#
# ~\anaconda3\lib\site-packages\valorant\client.py in get_match(self, id)
#     280
#     281     def get_match(self, id: t.Text) -> t.Optional[MatchDTO]:
# --> 282         r = self.handle.call("GET", "match", matchID=id, escape_if=(400, 404))
#     283
#     284         return MatchDTO(r) if r else None
#
# ~\anaconda3\lib\site-packages\valorant\caller.py in call(self, m, ep, escape_if, params, route, **kw)
#      55             return None
#      56
# ---> 57         return r.raise_for_status() or r.json()
#
# ~\anaconda3\lib\site-packages\requests\models.py in raise_for_status(self)
#    1019
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#    1023     def close(self):
#
# HTTPError: 403 Client Error: Forbidden for url: https://na.api.riotgames.com/val/match/v1/matches/c229a683-a205-4543-a174-522956e8b72d

# %%
client.get_session()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1228\1998935002.py in <module>
# ----> 1 client.get_session()
#
# ~\anaconda3\lib\site-packages\valorant\client.py in __getattribute__(self, name)
#      81
#      82     def __getattribute__(self, name):
# ---> 83         return super(Client, self).__getattribute__(name)
#      84
#      85     def asset(
#
# AttributeError: 'Client' object has no attribute 'get_session'

# %%
token = 'RGAPI-68e255f5-6d59-4152-b84b-35f67be5e3fe'

# %%
puuid = 'puuid=t6hgE7vM78zeB7VZqIF9BV4VC3xqSFyBQ_QaAK_l2xRSfxTqaTmh0Adqwc7V7QamAPszSWlTyDf2lg'

# %%
import requests
response = requests.get('https://br.api.riotgames.com/lol/summoner/v4/summoners/by-name/viikset', headers={'Authorization': f'Bearer token {token}'})

# %%
response.json()
# Out:
# {'status': {'message': 'Unauthorized', 'status_code': 401}}

# %% [markdown]
# # Main

# %%
import requests
import pandas as pd

# %%
users = {
    "viikset": "BR1",
    "TADALA": "BR1"
}

# %%
puuids = {
    "viikset": "f2f7c867-27ba-5291-a23c-bbdcfc079e76",
    "TADALA": "35a2368e-586f-53ec-8ee8-ea9ebdca7d6f",
    "DIGAOTJS": "2c51a2e4-0dcf-53f5-ae85-cd4d7d79f663",
    "mBirth": "6c241ab0-1c2f-5d5b-8908-4e809df8f6ca",
    "Kubata": "b2310858-1741-5d6f-8499-cb1f85bd182a"
}

# %%
response = requests.get("https://api.henrikdev.xyz/valorant/v1/account/viikset/BR1")

# %%
puuid = response.json().pop('data').pop('puuid')

# %%
response.json()['data']
# Out:
# {'puuid': 'f2f7c867-27ba-5291-a23c-bbdcfc079e76',
#  'region': 'na',
#  'account_level': 116,
#  'name': 'viikset',
#  'tag': 'BR1',
#  'card': {'small': 'https://media.valorant-api.com/playercards/fca32892-4f2f-228b-0f5c-209ad50199b3/smallart.png',
#   'large': 'https://media.valorant-api.com/playercards/fca32892-4f2f-228b-0f5c-209ad50199b3/largeart.png',
#   'wide': 'https://media.valorant-api.com/playercards/fca32892-4f2f-228b-0f5c-209ad50199b3/wideart.png',
#   'id': 'fca32892-4f2f-228b-0f5c-209ad50199b3'},
#  'last_update': '30 minutes ago',
#  'last_update_raw': 1679230916}

# %%
response = requests.get(f"https://api.henrikdev.xyz/valorant/v1/by-puuid/mmr/na/{puuid}")

# %%
response.json()
# Out:
# {'status': 200,
#  'data': {'currenttier': 10,
#   'currenttierpatched': 'Silver 2',
#   'images': {'small': 'https://media.valorant-api.com/competitivetiers/03621f52-342b-cf4e-4f86-9350a49c6d04/10/smallicon.png',
#    'large': 'https://media.valorant-api.com/competitivetiers/03621f52-342b-cf4e-4f86-9350a49c6d04/10/largeicon.png',
#    'triangle_down': 'https://media.valorant-api.com/competitivetiers/03621f52-342b-cf4e-4f86-9350a49c6d04/10/ranktriangledownicon.png',
#    'triangle_up': 'https://media.valorant-api.com/competitivetiers/03621f52-342b-cf4e-4f86-9350a49c6d04/10/ranktriangleupicon.png'},
#   'ranking_in_tier': 0,
#   'mmr_change_to_last_game': -15,
#   'elo': 700,
#   'name': 'viikset',
#   'tag': 'BR1',
#   'old': False}}

# %%
response = requests.get(f"https://api.henrikdev.xyz/valorant/v1/by-puuid/mmr-history/na/{puuid}")

# %%
pd.DataFrame(response.json()['data'])
# Out:
#    currenttier currenttierpatched  \
# 0           10           Silver 2
# 1           10           Silver 2
# 2           10           Silver 2
# 3           10           Silver 2
# 4           10           Silver 2
# 5           10           Silver 2
# 6           10           Silver 2
# 7           10           Silver 2
# 8           10           Silver 2
# 9           10           Silver 2
#
#                                               images  ranking_in_tier  \
# 0  {'small': 'https://media.valorant-api.com/comp...                0
# 1  {'small': 'https://media.valorant-api.com/comp...               15
# 2  {'small': 'https://media.valorant-api.com/comp...                5
# 3  {'small': 'https://media.valorant-api.com/comp...               24
# 4  {'small': 'https://media.valorant-api.com/comp...               38
# 5  {'small': 'https://media.valorant-api.com/comp...               53
# 6  {'small': 'https://media.valorant-api.com/comp...               66
# 7  {'small': 'https://media.valorant-api.com/comp...               80
# 8  {'small': 'https://media.valorant-api.com/comp...               63
# 9  {'small': 'https://media.valorant-api.com/comp...               42
#
#    mmr_change_to_last_game  elo                                date  \
# 0                      -15  700    Saturday, March 18, 2023 9:09 PM
# 1                       10  715    Saturday, March 18, 2023 8:17 PM
# 2                      -19  705     Sunday, March 12, 2023 10:47 PM
# 3                      -14  724     Sunday, March 12, 2023 10:10 PM
# 4                      -15  738      Sunday, March 12, 2023 9:24 PM
# 5                      -13  753   Saturday, March 11, 2023 11:47 PM
# 6                      -14  766   Saturday, March 11, 2023 11:06 PM
# 7                       17  780   Saturday, March 11, 2023 10:11 PM
# 8                       21  763    Saturday, March 11, 2023 9:36 PM
# 9                       24  742  Sunday, February 12, 2023 10:33 PM
#
#      date_raw
# 0  1679170164
# 1  1679167041
# 2  1678657659
# 3  1678655418
# 4  1678652656
# 5  1678574871
# 6  1678572403
# 7  1678569104
# 8  1678567000
# 9  1676237625

# %%
response = requests.get(f"https://api.henrikdev.xyz/valorant/v3/by-puuid/matches/na/{puuid}")

# %%
matchs_history = response

# %%
matchid = matchs_history.json()['data'][3]['metadata']['matchid']

# %%
response = requests.get(f"https://api.henrikdev.xyz/valorant/v2/match/{matchid}")

# %%
response.json()
# Out:
# {'status': 200,
#  'data': {'metadata': {'map': 'Icebox',
#    'game_version': 'release-06.04-shipping-13-837750',
#    'game_length': 2065979,
#    'game_start': 1678655418,
#    'game_start_patched': 'Sunday, March 12, 2023 10:10 PM',
#    'rounds_played': 20,
#    'mode': 'Competitive',
#    'queue': 'Standard',
#    'season_id': '34093c29-4306-43de-452f-3f944bde22be',
#    'platform': 'PC',
#    'matchid': '3d1e95f9-7c31-42ce-9f1f-ac5b772551e8',
#    'region': 'na',
#    'cluster': 'Sao Paulo'},
#   'players': {'all_players': [{'puuid': '55e10892-343a-52e1-a697-6d7c61ba6b01',
#      'name': 'SakurajimaSenpai',
#      'tag': 'Virge',
#      'team': 'Red',
#      'level': 62,
#      'character': 'Yoru',
#      'currenttier': 9,
#      'currenttier_patched': 'Silver 1',
#      'player_card': '2dfbdbf2-4f2d-328e-01d8-f5a6f0a92318',
#      'player_title': '25c60422-4246-fe96-9ac1-d88e7a379571',
#      'party_id': '905d83d1-1272-49e9-a55d-c96d58060fdf',
#      'session_playtime': {'minutes': 124,
#       'seconds': 7440,
#       'milliseconds': 7440000},
#      'behavior': {'afk_rounds': 0,
#       'friendly_fire': {'incoming': 0, 'outgoing': 0},
#       'rounds_in_spawn': 0},
#      'platform': {'type': 'PC',
#       'os': {'name': 'Windows', 'version': '10.0.22621.1.256.64bit'}},
#      'ability_casts': {'c_cast': 10, 'q_cast': 24, 'e_cast': 28, 'x_cast': 3},
#      'assets': {'card': {'small': 'https://media.valorant-api.com/playercards/2dfbdbf2-4f2d-328e-01d8-f5a6f0a92318/smallart.png',
#        'large': 'https://media.valorant-api.com/playercards/2dfbdbf2-4f2d-328e-01d8-f5a6f0a92318/largeart.png',
#        'wide': 'https://media.valorant-api.com/playercards/2dfbdbf2-4f2d-328e-01d8-f5a6f0a92318/wideart.png'},
#       'agent': {'small': 'https://media.valorant-api.com/agents/7f94d92c-4234-0a36-9646-3a87eb8b5c89/displayicon.png',
#        'bust': 'https://media.valorant-api.com/agents/7f94d92c-4234-0a36-9646-3a87eb8b5c89/bustportrait.png',
#        'full': 'https://media.valorant-api.com/agents/7f94d92c-4234-0a36-9646-3a87eb8b5c89/fullportrait.png',
#        'killfeed': 'https://media.valorant-api.com/agents/7f94d92c-4234-0a36-9646-3a87eb8b5c89/killfeedportrait.png'}},
#      'stats': {'score': 3308,
#       'kills': 12,
#       'deaths': 15,
#       'assists': 5,
#       'bodyshots': 39,
#       'headshots': 4,
#       'legshots': 6},
#      'economy': {'spent': {'overall': 50050, 'average': 2503},
#       'loadout_value': {'overall': 76000, 'average': 3800}},
#      'damage_made': 2063,
#      'damage_received': 2613},
#     {'puuid': '35a2368e-586f-53ec-8ee8-ea9ebdca7d6f',
#      'name': 'TADALA',
#      'tag': 'TADAL',
#      'team': 'Blue',
#      'level': 146,
#      'character': 'Harbor',
#      'currenttier': 8,
#      'currenttier_patched': 'Bronze 3',
#      'player_card': '867e85c2-4f4e-797b-7c94-a0b403fe22f3',
#      'player_title': '42e2f97d-4e69-274c-589c-0fbdeb397df9',
#      'party_id': 'efac9003-38d0-4750-b5f7-bd98ab81b9ef',
#      'session_playtime': {'minutes': 119,
#       'seconds': 7140,
#       'milliseconds': 7140000},
#      'behavior': {'afk_rounds': 0,
#       'friendly_fire': {'incoming': 0, 'outgoing': 0},
#       'rounds_in_spawn': 0},
#      'platform': {'type': 'PC',
#       'os': {'name': 'Windows', 'version': '10.0.19045.1.768.64bit'}},
#      'ability_casts': {'c_cast': 23, 'q_cast': 2, 'e_cast': 5, 'x_cast': 3},
#      'assets': {'card': {'small': 'https://media.valorant-api.com/playercards/867e85c2-4f4e-797b-7c94-a0b403fe22f3/smallart.png',
#        'large': 'https://media.valorant-api.com/playercards/867e85c2-4f4e-797b-7c94-a0b403fe22f3/largeart.png',
#        'wide': 'https://media.valorant-api.com/playercards/867e85c2-4f4e-797b-7c94-a0b403fe22f3/wideart.png'},
#       'agent': {'small': 'https://media.valorant-api.com/agents/95b78ed7-4637-86d9-7e41-71ba8c293152/displayicon.png',
#        'bust': 'https://media.valorant-api.com/agents/95b78ed7-4637-86d9-7e41-71ba8c293152/bustportrait.png',
#        'full': 'https://media.valorant-api.com/agents/95b78ed7-4637-86d9-7e41-71ba8c293152/fullportrait.png',
#        'killfeed': 'https://media.valorant-api.com/agents/95b78ed7-4637-86d9-7e41-71ba8c293152/killfeedportrait.png'}},
#      'stats': {'score': 2993,
#       'kills': 11,
#       'deaths': 18,
#       'assists': 3,
#       'bodyshots': 32,
#       'headshots': 4,
#       'legshots': 14},
#      'economy': {'spent': {'overall': 50400, 'average': 2520},
#       'loadout_value': {'overall': 61400, 'average': 3070}},
#      'damage_made': 1673,
#      'damage_received': 2977},
#     {'puuid': '6a91f483-ea58-54de-bf9b-de6ea23ba5e6',
#      'name': 'Adam Barlyn',
#      'tag': 'BR1',
#      'team': 'Red',
#      'level': 49,
#      'character': 'Fade',
#      'currenttier': 8,
#      'currenttier_patched': 'Bronze 3',
#      'player_card': '36377e6d-4be8-a585-f4a6-4fbdbb697324',
#      'player_title': '41c01df4-4d3d-d08d-58d4-e198763019f2',
#      'party_id': '905d83d1-1272-49e9-a55d-c96d58060fdf',
#      'session_playtime': {'minutes': 25,
#       'seconds': 1500,
#       'milliseconds': 1500000},
#      'behavior': {'afk_rounds': 0,
#       'friendly_fire': {'incoming': 0, 'outgoing': 0},
#       'rounds_in_spawn': 0},
#      'platform': {'type': 'PC',
#       'os': {'name': 'Windows', 'version': '10.0.19044.1.256.64bit'}},
#      'ability_casts': {'c_cast': 15, 'q_cast': 1, 'e_cast': 24, 'x_cast': 2},
#      'assets': {'card': {'small': 'https://media.valorant-api.com/playercards/36377e6d-4be8-a585-f4a6-4fbdbb697324/smallart.png',
#        'large': 'https://media.valorant-api.com/playercards/36377e6d-4be8-a585-f4a6-4fbdbb697324/largeart.png',
#        'wide': 'https://media.valorant-api.com/playercards/36377e6d-4be8-a585-f4a6-4fbdbb697324/wideart.png'},
#       'agent': {'small': 'https://media.valorant-api.com/agents/dade69b4-4f5a-8528-247b-219e5a1facd6/displayicon.png',
#        'bust': 'https://media.valorant-api.com/agents/dade69b4-4f5a-8528-247b-219e5a1facd6/bustportrait.png',
#        'full': 'https://media.valorant-api.com/agents/dade69b4-4f5a-8528-247b-219e5a1facd6/fullportrait.png',
#        'killfeed': 'https://media.valorant-api.com/agents/dade69b4-4f5a-8528-247b-219e5a1facd6/killfeedportrait.png'}},
#      'stats': {'score': 2423,
#       'kills': 9,
#       'deaths': 12,
#       'assists': 5,
#       'bodyshots': 32,
#       'headshots': 13,
#       'legshots': 3},
#      'economy': {'spent': {'overall': 41700, 'average': 2085},
#       'loadout_value': {'overall': 66650, 'average': 3333}},
#      'damage_made': 1435,
#      'damage_received': 2111},
#     {'puuid': 'b2310858-1741-5d6f-8499-cb1f85bd182a',
#      'name': 'Kubata',
#      'tag': '4881',
#      'team': 'Blue',
#      'level': 47,
#      'character': 'Phoenix',
#      'currenttier': 8,
#      'currenttier_patched': 'Bronze 3',
#      'player_card': 'f09db5d0-42a0-6225-588d-e3b92ef956d5',
#      'player_title': '566b6a77-4f72-af35-6d17-43be14e73cb7',
#      'party_id': 'efac9003-38d0-4750-b5f7-bd98ab81b9ef',
#      'session_playtime': {'minutes': 100,
#       'seconds': 6000,
#       'milliseconds': 6000000},
#      'behavior': {'afk_rounds': 0,
#       'friendly_fire': {'incoming': 0, 'outgoing': 0},
#       'rounds_in_spawn': 0},
#      'platform': {'type': 'PC',
#       'os': {'name': 'Windows', 'version': '10.0.19043.1.256.64bit'}},
#      'ability_casts': {'c_cast': 0, 'q_cast': 7, 'e_cast': 6, 'x_cast': 3},
#      'assets': {'card': {'small': 'https://media.valorant-api.com/playercards/f09db5d0-42a0-6225-588d-e3b92ef956d5/smallart.png',
#        'large': 'https://media.valorant-api.com/playercards/f09db5d0-42a0-6225-588d-e3b92ef956d5/largeart.png',
#        'wide': 'https://media.valorant-api.com/playercards/f09db5d0-42a0-6225-588d-e3b92ef956d5/wideart.png'},
#       'agent': {'small': 'https://media.valorant-api.com/agents/eb93336a-449b-9c1b-0a54-a891f7921d69/displayicon.png',
#        'bust': 'https://media.valorant-api.com/agents/eb93336a-449b-9c1b-0a54-a891f7921d69/bustportrait.png',
#        'full': 'https://media.valorant-api.com/agents/eb93336a-449b-9c1b-0a54-a891f7921d69/fullportrait.png',
#        'killfeed': 'https://media.valorant-api.com/agents/eb93336a-449b-9c1b-0a54-a891f7921d69/killfeedportrait.png'}},
#      'stats': {'score': 3929,
#       'kills': 14,
#       'deaths': 16,
#       'assists': 4,
#       'bodyshots': 30,
#       'headshots': 9,
#       'legshots': 1},
#      'economy': {'spent': {'overall': 50500, 'average': 2525},
#       'loadout_value': {'overall': 72150, 'average': 3608}},
#      'damage_made': 2608,
#      'damage_received': 3115},
#     {'puuid': '2c51a2e4-0dcf-53f5-ae85-cd4d7d79f663',
#      'name': 'DIGAOTJS',
#      'tag': 'BR1',
#      'team': 'Blue',
#      'level': 78,
#      'character': 'Yoru',
#      'currenttier': 9,
#      'currenttier_patched': 'Silver 1',
#      'player_card': '514ea59a-448c-ba70-9ebb-5faff372b6e2',
#      'player_title': '631f4283-48b1-1855-d646-5e8f80e29821',
#      'party_id': 'efac9003-38d0-4750-b5f7-bd98ab81b9ef',
#      'session_playtime': {'minutes': 92,
#       'seconds': 5520,
#       'milliseconds': 5520000},
#      'behavior': {'afk_rounds': 0,
#       'friendly_fire': {'incoming': 0, 'outgoing': 0},
#       'rounds_in_spawn': 0},
#      'platform': {'type': 'PC',
#       'os': {'name': 'Windows', 'version': '10.0.19044.1.768.64bit'}},
#      'ability_casts': {'c_cast': 9, 'q_cast': 11, 'e_cast': 14, 'x_cast': 4},
#      'assets': {'card': {'small': 'https://media.valorant-api.com/playercards/514ea59a-448c-ba70-9ebb-5faff372b6e2/smallart.png',
#        'large': 'https://media.valorant-api.com/playercards/514ea59a-448c-ba70-9ebb-5faff372b6e2/largeart.png',
#        'wide': 'https://media.valorant-api.com/playercards/514ea59a-448c-ba70-9ebb-5faff372b6e2/wideart.png'},
#       'agent': {'small': 'https://media.valorant-api.com/agents/7f94d92c-4234-0a36-9646-3a87eb8b5c89/displayicon.png',
#        'bust': 'https://media.valorant-api.com/agents/7f94d92c-4234-0a36-9646-3a87eb8b5c89/bustportrait.png',
#        'full': 'https://media.valorant-api.com/agents/7f94d92c-4234-0a36-9646-3a87eb8b5c89/fullportrait.png',
#        'killfeed': 'https://media.valorant-api.com/agents/7f94d92c-4234-0a36-9646-3a87eb8b5c89/killfeedportrait.png'}},
#      'stats': {'score': 6885,
#       'kills': 23,
#       'deaths': 15,
#       'assists': 4,
#       'bodyshots': 65,
#       'headshots': 10,
#       'legshots': 4},
#      'economy': {'spent': {'overall': 52950, 'average': 2648},
#       'loadout_value': {'overall': 72600, 'average': 3630}},
#      'damage_made': 4004,
#      'damage_received': 2942},
#     {'puuid': 'f2f7c867-27ba-5291-a23c-bbdcfc079e76',
#      'name': 'viikset',
#      'tag': 'BR1',
#      'team': 'Blue',
#      'level': 115,
#      'character': 'Sage',
#      'currenttier': 10,
#      'currenttier_patched': 'Silver 2',
#      'player_card': 'fca32892-4f2f-228b-0f5c-209ad50199b3',
#      'player_title': '2d284b12-4536-1d0e-b08c-e58850b2a76e',
#      'party_id': 'efac9003-38d0-4750-b5f7-bd98ab81b9ef',
#      'session_playtime': {'minutes': 65,
#       'seconds': 3900,
#       'milliseconds': 3900000},
#      'behavior': {'afk_rounds': 0,
#       'friendly_fire': {'incoming': 0, 'outgoing': 0},
#       'rounds_in_spawn': 0},
#      'platform': {'type': 'PC',
#       'os': {'name': 'Windows', 'version': '10.0.19044.1.256.64bit'}},
#      'ability_casts': {'c_cast': 10, 'q_cast': 7, 'e_cast': 7, 'x_cast': 0},
#      'assets': {'card': {'small': 'https://media.valorant-api.com/playercards/fca32892-4f2f-228b-0f5c-209ad50199b3/smallart.png',
#        'large': 'https://media.valorant-api.com/playercards/fca32892-4f2f-228b-0f5c-209ad50199b3/largeart.png',
#        'wide': 'https://media.valorant-api.com/playercards/fca32892-4f2f-228b-0f5c-209ad50199b3/wideart.png'},
#       'agent': {'small': 'https://media.valorant-api.com/agents/569fdd95-4d10-43ab-ca70-79becc718b46/displayicon.png',
#        'bust': 'https://media.valorant-api.com/agents/569fdd95-4d10-43ab-ca70-79becc718b46/bustportrait.png',
#        'full': 'https://media.valorant-api.com/agents/569fdd95-4d10-43ab-ca70-79becc718b46/fullportrait.png',
#        'killfeed': 'https://media.valorant-api.com/agents/569fdd95-4d10-43ab-ca70-79becc718b46/killfeedportrait.png'}},
#      'stats': {'score': 3528,
#       'kills': 12,
#       'deaths': 15,
#       'assists': 3,
#       'bodyshots': 33,
#       'headshots': 6,
#       'legshots': 8},
#      'economy': {'spent': {'overall': 50950, 'average': 2548},
#       'loadout_value': {'overall': 71950, 'average': 3598}},
#      'damage_made': 2313,
#      'damage_received': 2817},
#     {'puuid': '624fadb6-52f7-555a-b5d7-f9b3c3a48811',
#      'name': 'Victor',
#      'tag': '01508',
#      'team': 'Red',
#      'level': 172,
#      'character': 'Omen',
#      'currenttier': 0,
#      'currenttier_patched': 'Unrated',
#      'player_card': '2a280896-4e81-c319-ffd3-6b8873042647',
#      'player_title': '703cd95a-4624-16f3-fdd9-f4a881993577',
#      'party_id': '905d83d1-1272-49e9-a55d-c96d58060fdf',
#      'session_playtime': {'minutes': 16,
#       'seconds': 960,
#       'milliseconds': 960000},
#      'behavior': {'afk_rounds': 0,
#       'friendly_fire': {'incoming': 0, 'outgoing': 0},
#       'rounds_in_spawn': 0},
#      'platform': {'type': 'PC',
#       'os': {'name': 'Windows', 'version': '10.0.19044.1.256.64bit'}},
#      'ability_casts': {'c_cast': 8, 'q_cast': 9, 'e_cast': 24, 'x_cast': 1},
#      'assets': {'card': {'small': 'https://media.valorant-api.com/playercards/2a280896-4e81-c319-ffd3-6b8873042647/smallart.png',
#        'large': 'https://media.valorant-api.com/playercards/2a280896-4e81-c319-ffd3-6b8873042647/largeart.png',
#        'wide': 'https://media.valorant-api.com/playercards/2a280896-4e81-c319-ffd3-6b8873042647/wideart.png'},
#       'agent': {'small': 'https://media.valorant-api.com/agents/8e253930-4c05-31dd-1b6c-968525494517/displayicon.png',
#        'bust': 'https://media.valorant-api.com/agents/8e253930-4c05-31dd-1b6c-968525494517/bustportrait.png',
#        'full': 'https://media.valorant-api.com/agents/8e253930-4c05-31dd-1b6c-968525494517/fullportrait.png',
#        'killfeed': 'https://media.valorant-api.com/agents/8e253930-4c05-31dd-1b6c-968525494517/killfeedportrait.png'}},
#      'stats': {'score': 5932,
#       'kills': 20,
#       'deaths': 13,
#       'assists': 4,
#       'bodyshots': 47,
#       'headshots': 13,
#       'legshots': 1},
#      'economy': {'spent': {'overall': 47400, 'average': 2370},
#       'loadout_value': {'overall': 70650, 'average': 3533}},
#      'damage_made': 3856,
#      'damage_received': 2454},
#     {'puuid': '7e7baebf-2828-5788-8846-70972f13c6bd',
#      'name': 'homem rocha',
#      'tag': '2376',
#      'team': 'Red',
#      'level': 45,
#      'character': 'Killjoy',
#      'currenttier': 10,
#      'currenttier_patched': 'Silver 2',
#      'player_card': 'f09db5d0-42a0-6225-588d-e3b92ef956d5',
#      'player_title': 'bf097526-4503-6b17-2859-49a67bde66d2',
#      'party_id': '905d83d1-1272-49e9-a55d-c96d58060fdf',
#      'session_playtime': {'minutes': 75,
#       'seconds': 4500,
#       'milliseconds': 4500000},
#      'behavior': {'afk_rounds': 0,
#       'friendly_fire': {'incoming': 0, 'outgoing': 0},
#       'rounds_in_spawn': 0},
#      'platform': {'type': 'PC',
#       'os': {'name': 'Windows', 'version': '10.0.19045.1.768.64bit'}},
#      'ability_casts': {'c_cast': 7, 'q_cast': 8, 'e_cast': 4, 'x_cast': 3},
#      'assets': {'card': {'small': 'https://media.valorant-api.com/playercards/f09db5d0-42a0-6225-588d-e3b92ef956d5/smallart.png',
#        'large': 'https://media.valorant-api.com/playercards/f09db5d0-42a0-6225-588d-e3b92ef956d5/largeart.png',
#        'wide': 'https://media.valorant-api.com/playercards/f09db5d0-42a0-6225-588d-e3b92ef956d5/wideart.png'},
#       'agent': {'small': 'https://media.valorant-api.com/agents/1e58de9c-4950-5125-93e9-a0aee9f98746/displayicon.png',
#        'bust': 'https://media.valorant-api.com/agents/1e58de9c-4950-5125-93e9-a0aee9f98746/bustportrait.png',
#        'full': 'https://media.valorant-api.com/agents/1e58de9c-4950-5125-93e9-a0aee9f98746/fullportrait.png',
#        'killfeed': 'https://media.valorant-api.com/agents/1e58de9c-4950-5125-93e9-a0aee9f98746/killfeedportrait.png'}},
#      'stats': {'score': 5470,
#       'kills': 21,
#       'deaths': 11,
#       'assists': 2,
#       'bodyshots': 79,
#       'headshots': 8,
#       'legshots': 2},
#      'economy': {'spent': {'overall': 48000, 'average': 2400},
#       'loadout_value': {'overall': 75100, 'average': 3755}},
#      'damage_made': 3181,
#      'damage_received': 2175},
#     {'puuid': 'c8b9ccaf-b781-58b9-b917-95a5599b02e1',
#      'name': 'CdB Lula2023',
#      'tag': '9351',
#      'team': 'Red',
#      'level': 256,
#      'character': 'Sage',
#      'currenttier': 8,
#      'currenttier_patched': 'Bronze 3',
#      'player_card': '0d62fdfb-482e-2ddf-87eb-7ca7c88f222f',
#      'player_title': '0210a31e-41a0-6150-ee41-bd9d727b629b',
#      'party_id': '905d83d1-1272-49e9-a55d-c96d58060fdf',
#      'session_playtime': {'minutes': 113,
#       'seconds': 6780,
#       'milliseconds': 6780000},
#      'behavior': {'afk_rounds': 0,
#       'friendly_fire': {'incoming': 0, 'outgoing': 0},
#       'rounds_in_spawn': 0},
#      'platform': {'type': 'PC',
#       'os': {'name': 'Windows', 'version': '10.0.19044.1.768.64bit'}},
#      'ability_casts': {'c_cast': 5, 'q_cast': 14, 'e_cast': 8, 'x_cast': 2},
#      'assets': {'card': {'small': 'https://media.valorant-api.com/playercards/0d62fdfb-482e-2ddf-87eb-7ca7c88f222f/smallart.png',
#        'large': 'https://media.valorant-api.com/playercards/0d62fdfb-482e-2ddf-87eb-7ca7c88f222f/largeart.png',
#        'wide': 'https://media.valorant-api.com/playercards/0d62fdfb-482e-2ddf-87eb-7ca7c88f222f/wideart.png'},
#       'agent': {'small': 'https://media.valorant-api.com/agents/569fdd95-4d10-43ab-ca70-79becc718b46/displayicon.png',
#        'bust': 'https://media.valorant-api.com/agents/569fdd95-4d10-43ab-ca70-79becc718b46/bustportrait.png',
#        'full': 'https://media.valorant-api.com/agents/569fdd95-4d10-43ab-ca70-79becc718b46/fullportrait.png',
#        'killfeed': 'https://media.valorant-api.com/agents/569fdd95-4d10-43ab-ca70-79becc718b46/killfeedportrait.png'}},
#      'stats': {'score': 5766,
#       'kills': 17,
#       'deaths': 15,
#       'assists': 11,
#       'bodyshots': 59,
#       'headshots': 13,
#       'legshots': 16},
#      'economy': {'spent': {'overall': 46400, 'average': 2320},
#       'loadout_value': {'overall': 62300, 'average': 3115}},
#      'damage_made': 4132,
#      'damage_received': 2458},
#     {'puuid': '6c241ab0-1c2f-5d5b-8908-4e809df8f6ca',
#      'name': 'mBirth',
#      'tag': 'BR1',
#      'team': 'Blue',
#      'level': 84,
#      'character': 'Viper',
#      'currenttier': 5,
#      'currenttier_patched': 'Iron 3',
#      'player_card': '863afcf3-486a-3c96-4c23-9eb00def70d5',
#      'player_title': '349d430a-445f-c87e-cc8d-38bc2a86213a',
#      'party_id': 'efac9003-38d0-4750-b5f7-bd98ab81b9ef',
#      'session_playtime': {'minutes': 124,
#       'seconds': 7440,
#       'milliseconds': 7440000},
#      'behavior': {'afk_rounds': 0,
#       'friendly_fire': {'incoming': 0, 'outgoing': 0},
#       'rounds_in_spawn': 0},
#      'platform': {'type': 'PC',
#       'os': {'name': 'Windows', 'version': '10.0.19045.1.256.64bit'}},
#      'ability_casts': {'c_cast': 14, 'q_cast': 5, 'e_cast': 18, 'x_cast': 2},
#      'assets': {'card': {'small': 'https://media.valorant-api.com/playercards/863afcf3-486a-3c96-4c23-9eb00def70d5/smallart.png',
#        'large': 'https://media.valorant-api.com/playercards/863afcf3-486a-3c96-4c23-9eb00def70d5/largeart.png',
#        'wide': 'https://media.valorant-api.com/playercards/863afcf3-486a-3c96-4c23-9eb00def70d5/wideart.png'},
#       'agent': {'small': 'https://media.valorant-api.com/agents/707eab51-4836-f488-046a-cda6bf494859/displayicon.png',
#        'bust': 'https://media.valorant-api.com/agents/707eab51-4836-f488-046a-cda6bf494859/bustportrait.png',
#        'full': 'https://media.valorant-api.com/agents/707eab51-4836-f488-046a-cda6bf494859/fullportrait.png',
#        'killfeed': 'https://media.valorant-api.com/agents/707eab51-4836-f488-046a-cda6bf494859/killfeedportrait.png'}},
#      'stats': {'score': 1829,
#       'kills': 6,
#       'deaths': 15,
#       'assists': 3,
#       'bodyshots': 21,
#       'headshots': 5,
#       'legshots': 3},
#      'economy': {'spent': {'overall': 49400, 'average': 2470},
#       'loadout_value': {'overall': 67650, 'average': 3383}},
#      'damage_made': 1198,
#      'damage_received': 2801}],
#    'red': [{'puuid': '55e10892-343a-52e1-a697-6d7c61ba6b01',
#      'name': 'SakurajimaSenpai',
#      'tag': 'Virge',
#      'team': 'Red',
#      'level': 62,
#      'character': 'Yoru',
#      'currenttier': 9,
#      'currenttier_patched': 'Silver 1',
#      'player_card': '2dfbdbf2-4f2d-328e-01d8-f5a6f0a92318',
#      'player_title': '25c60422-4246-fe96-9ac1-d88e7a379571',
#      'party_id': '905d83d1-1272-49e9-a55d-c96d58060fdf',
#      'session_playtime': {'minutes': 124,
#       'seconds': 7440,
#       'milliseconds': 7440000},
#      'behavior': {'afk_rounds': 0,
#       'friendly_fire': {'incoming': 0, 'outgoing': 0},
#       'rounds_in_spawn': 0},
#      'platform': {'type': 'PC',
#       'os': {'name': 'Windows', 'version': '10.0.22621.1.256.64bit'}},
#      'ability_casts': {'c_cast': 10, 'q_cast': 24, 'e_cast': 28, 'x_cast': 3},
#      'assets': {'card': {'small': 'https://media.valorant-api.com/playercards/2dfbdbf2-4f2d-328e-01d8-f5a6f0a92318/smallart.png',
#        'large': 'https://media.valorant-api.com/playercards/2dfbdbf2-4f2d-328e-01d8-f5a6f0a92318/largeart.png',
#        'wide': 'https://media.valorant-api.com/playercards/2dfbdbf2-4f2d-328e-01d8-f5a6f0a92318/wideart.png'},
#       'agent': {'small': 'https://media.valorant-api.com/agents/7f94d92c-4234-0a36-9646-3a87eb8b5c89/displayicon.png',
#        'bust': 'https://media.valorant-api.com/agents/7f94d92c-4234-0a36-9646-3a87eb8b5c89/bustportrait.png',
#        'full': 'https://media.valorant-api.com/agents/7f94d92c-4234-0a36-9646-3a87eb8b5c89/fullportrait.png',
#        'killfeed': 'https://media.valorant-api.com/agents/7f94d92c-4234-0a36-9646-3a87eb8b5c89/killfeedportrait.png'}},
#      'stats': {'score': 3308,
#       'kills': 12,
#       'deaths': 15,
#       'assists': 5,
#       'bodyshots': 39,
#       'headshots': 4,
#       'legshots': 6},
#      'economy': {'spent': {'overall': 50050, 'average': 2503},
#       'loadout_value': {'overall': 76000, 'average': 3800}},
#      'damage_made': 2063,
#      'damage_received': 2613},
#     {'puuid': '6a91f483-ea58-54de-bf9b-de6ea23ba5e6',
#      'name': 'Adam Barlyn',
#      'tag': 'BR1',
#      'team': 'Red',
#      'level': 49,
#      'character': 'Fade',
#      'currenttier': 8,
#      'currenttier_patched': 'Bronze 3',
#      'player_card': '36377e6d-4be8-a585-f4a6-4fbdbb697324',
#      'player_title': '41c01df4-4d3d-d08d-58d4-e198763019f2',
#      'party_id': '905d83d1-1272-49e9-a55d-c96d58060fdf',
#      'session_playtime': {'minutes': 25,
#       'seconds': 1500,
#       'milliseconds': 1500000},
#      'behavior': {'afk_rounds': 0,
#       'friendly_fire': {'incoming': 0, 'outgoing': 0},
#       'rounds_in_spawn': 0},
#      'platform': {'type': 'PC',
#       'os': {'name': 'Windows', 'version': '10.0.19044.1.256.64bit'}},
#      'ability_casts': {'c_cast': 15, 'q_cast': 1, 'e_cast': 24, 'x_cast': 2},
#      'assets': {'card': {'small': 'https://media.valorant-api.com/playercards/36377e6d-4be8-a585-f4a6-4fbdbb697324/smallart.png',
#        'large': 'https://media.valorant-api.com/playercards/36377e6d-4be8-a585-f4a6-4fbdbb697324/largeart.png',
#        'wide': 'https://media.valorant-api.com/playercards/36377e6d-4be8-a585-f4a6-4fbdbb697324/wideart.png'},
#       'agent': {'small': 'https://media.valorant-api.com/agents/dade69b4-4f5a-8528-247b-219e5a1facd6/displayicon.png',
#        'bust': 'https://media.valorant-api.com/agents/dade69b4-4f5a-8528-247b-219e5a1facd6/bustportrait.png',
#        'full': 'https://media.valorant-api.com/agents/dade69b4-4f5a-8528-247b-219e5a1facd6/fullportrait.png',
#        'killfeed': 'https://media.valorant-api.com/agents/dade69b4-4f5a-8528-247b-219e5a1facd6/killfeedportrait.png'}},
#      'stats': {'score': 2423,
#       'kills': 9,
#       'deaths': 12,
#       'assists': 5,
#       'bodyshots': 32,
#       'headshots': 13,
#       'legshots': 3},
#      'economy': {'spent': {'overall': 41700, 'average': 2085},
#       'loadout_value': {'overall': 66650, 'average': 3333}},
#      'damage_made': 1435,
#      'damage_received': 2111},
#     {'puuid': '624fadb6-52f7-555a-b5d7-f9b3c3a48811',
#      'name': 'Victor',
#      'tag': '01508',
#      'team': 'Red',
#      'level': 172,
#      'character': 'Omen',
#      'currenttier': 0,
#      'currenttier_patched': 'Unrated',
#      'player_card': '2a280896-4e81-c319-ffd3-6b8873042647',
#      'player_title': '703cd95a-4624-16f3-fdd9-f4a881993577',
#      'party_id': '905d83d1-1272-49e9-a55d-c96d58060fdf',
#      'session_playtime': {'minutes': 16,
#       'seconds': 960,
#       'milliseconds': 960000},
#      'behavior': {'afk_rounds': 0,
#       'friendly_fire': {'incoming': 0, 'outgoing': 0},
#       'rounds_in_spawn': 0},
#      'platform': {'type': 'PC',
#       'os': {'name': 'Windows', 'version': '10.0.19044.1.256.64bit'}},
#      'ability_casts': {'c_cast': 8, 'q_cast': 9, 'e_cast': 24, 'x_cast': 1},
#      'assets': {'card': {'small': 'https://media.valorant-api.com/playercards/2a280896-4e81-c319-ffd3-6b8873042647/smallart.png',
#        'large': 'https://media.valorant-api.com/playercards/2a280896-4e81-c319-ffd3-6b8873042647/largeart.png',
#        'wide': 'https://media.valorant-api.com/playercards/2a280896-4e81-c319-ffd3-6b8873042647/wideart.png'},
#       'agent': {'small': 'https://media.valorant-api.com/agents/8e253930-4c05-31dd-1b6c-968525494517/displayicon.png',
#        'bust': 'https://media.valorant-api.com/agents/8e253930-4c05-31dd-1b6c-968525494517/bustportrait.png',
#        'full': 'https://media.valorant-api.com/agents/8e253930-4c05-31dd-1b6c-968525494517/fullportrait.png',
#        'killfeed': 'https://media.valorant-api.com/agents/8e253930-4c05-31dd-1b6c-968525494517/killfeedportrait.png'}},
#      'stats': {'score': 5932,
#       'kills': 20,
#       'deaths': 13,
#       'assists': 4,
#       'bodyshots': 47,
#       'headshots': 13,
#       'legshots': 1},
#      'economy': {'spent': {'overall': 47400, 'average': 2370},
#       'loadout_value': {'overall': 70650, 'average': 3533}},
#      'damage_made': 3856,
#      'damage_received': 2454},
#     {'puuid': '7e7baebf-2828-5788-8846-70972f13c6bd',
#      'name': 'homem rocha',
#      'tag': '2376',
#      'team': 'Red',
#      'level': 45,
#      'character': 'Killjoy',
#      'currenttier': 10,
#      'currenttier_patched': 'Silver 2',
#      'player_card': 'f09db5d0-42a0-6225-588d-e3b92ef956d5',
#      'player_title': 'bf097526-4503-6b17-2859-49a67bde66d2',
#      'party_id': '905d83d1-1272-49e9-a55d-c96d58060fdf',
#      'session_playtime': {'minutes': 75,
#       'seconds': 4500,
#       'milliseconds': 4500000},
#      'behavior': {'afk_rounds': 0,
#       'friendly_fire': {'incoming': 0, 'outgoing': 0},
#       'rounds_in_spawn': 0},
#      'platform': {'type': 'PC',
#       'os': {'name': 'Windows', 'version': '10.0.19045.1.768.64bit'}},
#      'ability_casts': {'c_cast': 7, 'q_cast': 8, 'e_cast': 4, 'x_cast': 3},
#      'assets': {'card': {'small': 'https://media.valorant-api.com/playercards/f09db5d0-42a0-6225-588d-e3b92ef956d5/smallart.png',
#        'large': 'https://media.valorant-api.com/playercards/f09db5d0-42a0-6225-588d-e3b92ef956d5/largeart.png',
#        'wide': 'https://media.valorant-api.com/playercards/f09db5d0-42a0-6225-588d-e3b92ef956d5/wideart.png'},
#       'agent': {'small': 'https://media.valorant-api.com/agents/1e58de9c-4950-5125-93e9-a0aee9f98746/displayicon.png',
#        'bust': 'https://media.valorant-api.com/agents/1e58de9c-4950-5125-93e9-a0aee9f98746/bustportrait.png',
#        'full': 'https://media.valorant-api.com/agents/1e58de9c-4950-5125-93e9-a0aee9f98746/fullportrait.png',
#        'killfeed': 'https://media.valorant-api.com/agents/1e58de9c-4950-5125-93e9-a0aee9f98746/killfeedportrait.png'}},
#      'stats': {'score': 5470,
#       'kills': 21,
#       'deaths': 11,
#       'assists': 2,
#       'bodyshots': 79,
#       'headshots': 8,
#       'legshots': 2},
#      'economy': {'spent': {'overall': 48000, 'average': 2400},
#       'loadout_value': {'overall': 75100, 'average': 3755}},
#      'damage_made': 3181,
#      'damage_received': 2175},
#     {'puuid': 'c8b9ccaf-b781-58b9-b917-95a5599b02e1',
#      'name': 'CdB Lula2023',
#      'tag': '9351',
#      'team': 'Red',
#      'level': 256,
#      'character': 'Sage',
#      'currenttier': 8,
#      'currenttier_patched': 'Bronze 3',
#      'player_card': '0d62fdfb-482e-2ddf-87eb-7ca7c88f222f',
#      'player_title': '0210a31e-41a0-6150-ee41-bd9d727b629b',
#      'party_id': '905d83d1-1272-49e9-a55d-c96d58060fdf',
#      'session_playtime': {'minutes': 113,
#       'seconds': 6780,
#       'milliseconds': 6780000},
#      'behavior': {'afk_rounds': 0,
#       'friendly_fire': {'incoming': 0, 'outgoing': 0},
#       'rounds_in_spawn': 0},
#      'platform': {'type': 'PC',
#       'os': {'name': 'Windows', 'version': '10.0.19044.1.768.64bit'}},
#      'ability_casts': {'c_cast': 5, 'q_cast': 14, 'e_cast': 8, 'x_cast': 2},
#      'assets': {'card': {'small': 'https://media.valorant-api.com/playercards/0d62fdfb-482e-2ddf-87eb-7ca7c88f222f/smallart.png',
#        'large': 'https://media.valorant-api.com/playercards/0d62fdfb-482e-2ddf-87eb-7ca7c88f222f/largeart.png',
#        'wide': 'https://media.valorant-api.com/playercards/0d62fdfb-482e-2ddf-87eb-7ca7c88f222f/wideart.png'},
#       'agent': {'small': 'https://media.valorant-api.com/agents/569fdd95-4d10-43ab-ca70-79becc718b46/displayicon.png',
#        'bust': 'https://media.valorant-api.com/agents/569fdd95-4d10-43ab-ca70-79becc718b46/bustportrait.png',
#        'full': 'https://media.valorant-api.com/agents/569fdd95-4d10-43ab-ca70-79becc718b46/fullportrait.png',
#        'killfeed': 'https://media.valorant-api.com/agents/569fdd95-4d10-43ab-ca70-79becc718b46/killfeedportrait.png'}},
#      'stats': {'score': 5766,
#       'kills': 17,
#       'deaths': 15,
#       'assists': 11,
#       'bodyshots': 59,
#       'headshots': 13,
#       'legshots': 16},
#      'economy': {'spent': {'overall': 46400, 'average': 2320},
#       'loadout_value': {'overall': 62300, 'average': 3115}},
#      'damage_made': 4132,
#      'damage_received': 2458}],
#    'blue': [{'puuid': '35a2368e-586f-53ec-8ee8-ea9ebdca7d6f',
#      'name': 'TADALA',
#      'tag': 'TADAL',
#      'team': 'Blue',
#      'level': 146,
#      'character': 'Harbor',
#      'currenttier': 8,
#      'currenttier_patched': 'Bronze 3',
#      'player_card': '867e85c2-4f4e-797b-7c94-a0b403fe22f3',
#      'player_title': '42e2f97d-4e69-274c-589c-0fbdeb397df9',
#      'party_id': 'efac9003-38d0-4750-b5f7-bd98ab81b9ef',
#      'session_playtime': {'minutes': 119,
#       'seconds': 7140,
#       'milliseconds': 7140000},
#      'behavior': {'afk_rounds': 0,
#       'friendly_fire': {'incoming': 0, 'outgoing': 0},
#       'rounds_in_spawn': 0},
#      'platform': {'type': 'PC',
#       'os': {'name': 'Windows', 'version': '10.0.19045.1.768.64bit'}},
#      'ability_casts': {'c_cast': 23, 'q_cast': 2, 'e_cast': 5, 'x_cast': 3},
#      'assets': {'card': {'small': 'https://media.valorant-api.com/playercards/867e85c2-4f4e-797b-7c94-a0b403fe22f3/smallart.png',
#        'large': 'https://media.valorant-api.com/playercards/867e85c2-4f4e-797b-7c94-a0b403fe22f3/largeart.png',
#        'wide': 'https://media.valorant-api.com/playercards/867e85c2-4f4e-797b-7c94-a0b403fe22f3/wideart.png'},
#       'agent': {'small': 'https://media.valorant-api.com/agents/95b78ed7-4637-86d9-7e41-71ba8c293152/displayicon.png',
#        'bust': 'https://media.valorant-api.com/agents/95b78ed7-4637-86d9-7e41-71ba8c293152/bustportrait.png',
#        'full': 'https://media.valorant-api.com/agents/95b78ed7-4637-86d9-7e41-71ba8c293152/fullportrait.png',
#        'killfeed': 'https://media.valorant-api.com/agents/95b78ed7-4637-86d9-7e41-71ba8c293152/killfeedportrait.png'}},
#      'stats': {'score': 2993,
#       'kills': 11,
#       'deaths': 18,
#       'assists': 3,
#       'bodyshots': 32,
#       'headshots': 4,
#       'legshots': 14},
#      'economy': {'spent': {'overall': 50400, 'average': 2520},
#       'loadout_value': {'overall': 61400, 'average': 3070}},
#      'damage_made': 1673,
#      'damage_received': 2977},
#     {'puuid': 'b2310858-1741-5d6f-8499-cb1f85bd182a',
#      'name': 'Kubata',
#      'tag': '4881',
#      'team': 'Blue',
#      'level': 47,
#      'character': 'Phoenix',
#      'currenttier': 8,
#      'currenttier_patched': 'Bronze 3',
#      'player_card': 'f09db5d0-42a0-6225-588d-e3b92ef956d5',
#      'player_title': '566b6a77-4f72-af35-6d17-43be14e73cb7',
#      'party_id': 'efac9003-38d0-4750-b5f7-bd98ab81b9ef',
#      'session_playtime': {'minutes': 100,
#       'seconds': 6000,
#       'milliseconds': 6000000},
#      'behavior': {'afk_rounds': 0,
#       'friendly_fire': {'incoming': 0, 'outgoing': 0},
#       'rounds_in_spawn': 0},
#      'platform': {'type': 'PC',
#       'os': {'name': 'Windows', 'version': '10.0.19043.1.256.64bit'}},
#      'ability_casts': {'c_cast': 0, 'q_cast': 7, 'e_cast': 6, 'x_cast': 3},
#      'assets': {'card': {'small': 'https://media.valorant-api.com/playercards/f09db5d0-42a0-6225-588d-e3b92ef956d5/smallart.png',
#        'large': 'https://media.valorant-api.com/playercards/f09db5d0-42a0-6225-588d-e3b92ef956d5/largeart.png',
#        'wide': 'https://media.valorant-api.com/playercards/f09db5d0-42a0-6225-588d-e3b92ef956d5/wideart.png'},
#       'agent': {'small': 'https://media.valorant-api.com/agents/eb93336a-449b-9c1b-0a54-a891f7921d69/displayicon.png',
#        'bust': 'https://media.valorant-api.com/agents/eb93336a-449b-9c1b-0a54-a891f7921d69/bustportrait.png',
#        'full': 'https://media.valorant-api.com/agents/eb93336a-449b-9c1b-0a54-a891f7921d69/fullportrait.png',
#        'killfeed': 'https://media.valorant-api.com/agents/eb93336a-449b-9c1b-0a54-a891f7921d69/killfeedportrait.png'}},
#      'stats': {'score': 3929,
#       'kills': 14,
#       'deaths': 16,
#       'assists': 4,
#       'bodyshots': 30,
#       'headshots': 9,
#       'legshots': 1},
#      'economy': {'spent': {'overall': 50500, 'average': 2525},
#       'loadout_value': {'overall': 72150, 'average': 3608}},
#      'damage_made': 2608,
#      'damage_received': 3115},
#     {'puuid': '2c51a2e4-0dcf-53f5-ae85-cd4d7d79f663',
#      'name': 'DIGAOTJS',
#      'tag': 'BR1',
#      'team': 'Blue',
#      'level': 78,
#      'character': 'Yoru',
#      'currenttier': 9,
#      'currenttier_patched': 'Silver 1',
#      'player_card': '514ea59a-448c-ba70-9ebb-5faff372b6e2',
#      'player_title': '631f4283-48b1-1855-d646-5e8f80e29821',
#      'party_id': 'efac9003-38d0-4750-b5f7-bd98ab81b9ef',
#      'session_playtime': {'minutes': 92,
#       'seconds': 5520,
#       'milliseconds': 5520000},
#      'behavior': {'afk_rounds': 0,
#       'friendly_fire': {'incoming': 0, 'outgoing': 0},
#       'rounds_in_spawn': 0},
#      'platform': {'type': 'PC',
#       'os': {'name': 'Windows', 'version': '10.0.19044.1.768.64bit'}},
#      'ability_casts': {'c_cast': 9, 'q_cast': 11, 'e_cast': 14, 'x_cast': 4},
#      'assets': {'card': {'small': 'https://media.valorant-api.com/playercards/514ea59a-448c-ba70-9ebb-5faff372b6e2/smallart.png',
#        'large': 'https://media.valorant-api.com/playercards/514ea59a-448c-ba70-9ebb-5faff372b6e2/largeart.png',
#        'wide': 'https://media.valorant-api.com/playercards/514ea59a-448c-ba70-9ebb-5faff372b6e2/wideart.png'},
#       'agent': {'small': 'https://media.valorant-api.com/agents/7f94d92c-4234-0a36-9646-3a87eb8b5c89/displayicon.png',
#        'bust': 'https://media.valorant-api.com/agents/7f94d92c-4234-0a36-9646-3a87eb8b5c89/bustportrait.png',
#        'full': 'https://media.valorant-api.com/agents/7f94d92c-4234-0a36-9646-3a87eb8b5c89/fullportrait.png',
#        'killfeed': 'https://media.valorant-api.com/agents/7f94d92c-4234-0a36-9646-3a87eb8b5c89/killfeedportrait.png'}},
#      'stats': {'score': 6885,
#       'kills': 23,
#       'deaths': 15,
#       'assists': 4,
#       'bodyshots': 65,
#       'headshots': 10,
#       'legshots': 4},
#      'economy': {'spent': {'overall': 52950, 'average': 2648},
#       'loadout_value': {'overall': 72600, 'average': 3630}},
#      'damage_made': 4004,
#      'damage_received': 2942},
#     {'puuid': 'f2f7c867-27ba-5291-a23c-bbdcfc079e76',
#      'name': 'viikset',
#      'tag': 'BR1',
#      'team': 'Blue',
#      'level': 115,
#      'character': 'Sage',
#      'currenttier': 10,
#      'currenttier_patched': 'Silver 2',
#      'player_card': 'fca32892-4f2f-228b-0f5c-209ad50199b3',
#      'player_title': '2d284b12-4536-1d0e-b08c-e58850b2a76e',
#      'party_id': 'efac9003-38d0-4750-b5f7-bd98ab81b9ef',
#      'session_playtime': {'minutes': 65,
#       'seconds': 3900,
#       'milliseconds': 3900000},
#      'behavior': {'afk_rounds': 0,
#       'friendly_fire': {'incoming': 0, 'outgoing': 0},
#       'rounds_in_spawn': 0},
#      'platform': {'type': 'PC',
#       'os': {'name': 'Windows', 'version': '10.0.19044.1.256.64bit'}},
#      'ability_casts': {'c_cast': 10, 'q_cast': 7, 'e_cast': 7, 'x_cast': 0},
#      'assets': {'card': {'small': 'https://media.valorant-api.com/playercards/fca32892-4f2f-228b-0f5c-209ad50199b3/smallart.png',
#        'large': 'https://media.valorant-api.com/playercards/fca32892-4f2f-228b-0f5c-209ad50199b3/largeart.png',
#        'wide': 'https://media.valorant-api.com/playercards/fca32892-4f2f-228b-0f5c-209ad50199b3/wideart.png'},
#       'agent': {'small': 'https://media.valorant-api.com/agents/569fdd95-4d10-43ab-ca70-79becc718b46/displayicon.png',
#        'bust': 'https://media.valorant-api.com/agents/569fdd95-4d10-43ab-ca70-79becc718b46/bustportrait.png',
#        'full': 'https://media.valorant-api.com/agents/569fdd95-4d10-43ab-ca70-79becc718b46/fullportrait.png',
#        'killfeed': 'https://media.valorant-api.com/agents/569fdd95-4d10-43ab-ca70-79becc718b46/killfeedportrait.png'}},
#      'stats': {'score': 3528,
#       'kills': 12,
#       'deaths': 15,
#       'assists': 3,
#       'bodyshots': 33,
#       'headshots': 6,
#       'legshots': 8},
#      'economy': {'spent': {'overall': 50950, 'average': 2548},
#       'loadout_value': {'overall': 71950, 'average': 3598}},
#      'damage_made': 2313,
#      'damage_received': 2817},
#     {'puuid': '6c241ab0-1c2f-5d5b-8908-4e809df8f6ca',
#      'name': 'mBirth',
#      'tag': 'BR1',
#      'team': 'Blue',
#      'level': 84,
#      'character': 'Viper',
#      'currenttier': 5,
#      'currenttier_patched': 'Iron 3',
#      'player_card': '863afcf3-486a-3c96-4c23-9eb00def70d5',
#      'player_title': '349d430a-445f-c87e-cc8d-38bc2a86213a',
#      'party_id': 'efac9003-38d0-4750-b5f7-bd98ab81b9ef',
#      'session_playtime': {'minutes': 124,
#       'seconds': 7440,
#       'milliseconds': 7440000},
#      'behavior': {'afk_rounds': 0,
#       'friendly_fire': {'incoming': 0, 'outgoing': 0},
#       'rounds_in_spawn': 0},
#      'platform': {'type': 'PC',
#       'os': {'name': 'Windows', 'version': '10.0.19045.1.256.64bit'}},
#      'ability_casts': {'c_cast': 14, 'q_cast': 5, 'e_cast': 18, 'x_cast': 2},
#      'assets': {'card': {'small': 'https://media.valorant-api.com/playercards/863afcf3-486a-3c96-4c23-9eb00def70d5/smallart.png',
#        'large': 'https://media.valorant-api.com/playercards/863afcf3-486a-3c96-4c23-9eb00def70d5/largeart.png',
#        'wide': 'https://media.valorant-api.com/playercards/863afcf3-486a-3c96-4c23-9eb00def70d5/wideart.png'},
#       'agent': {'small': 'https://media.valorant-api.com/agents/707eab51-4836-f488-046a-cda6bf494859/displayicon.png',
#        'bust': 'https://media.valorant-api.com/agents/707eab51-4836-f488-046a-cda6bf494859/bustportrait.png',
#        'full': 'https://media.valorant-api.com/agents/707eab51-4836-f488-046a-cda6bf494859/fullportrait.png',
#        'killfeed': 'https://media.valorant-api.com/agents/707eab51-4836-f488-046a-cda6bf494859/killfeedportrait.png'}},
#      'stats': {'score': 1829,
#       'kills': 6,
#       'deaths': 15,
#       'assists': 3,
#       'bodyshots': 21,
#       'headshots': 5,
#       'legshots': 3},
#      'economy': {'spent': {'overall': 49400, 'average': 2470},
#       'loadout_value': {'overall': 67650, 'average': 3383}},
#      'damage_made': 1198,
#      'damage_received': 2801}]},
#   'teams': {'red': {'has_won': True, 'rounds_won': 13, 'rounds_lost': 7},
#    'blue': {'has_won': False, 'rounds_won': 7, 'rounds_lost': 13}},
#   'rounds': [{'winning_team': 'Blue',
#     'end_type': 'Eliminated',
#     'bomb_planted': False,
#     'bomb_defused': False,
#     'plant_events': {'plant_location': None,
#      'planted_by': None,
#      'plant_site': None,
#      'plant_time_in_round': None,
#      'player_locations_on_plant': None},
#     'defuse_events': {'defuse_location': None,
#      'defused_by': None,
#      'defuse_time_in_round': None,
#      'player_locations_on_defuse': None},
#     'player_stats': [{'ability_casts': {'c_casts': None,
#        'q_casts': None,
#        'e_cast': None,
#        'x_cast': None},
#       'player_puuid': '55e10892-343a-52e1-a697-6d7c61ba6b01',
#       'player_display_name': 'SakurajimaSenpai#Virge',
#       'player_team': 'Red',
#       'damage_events': [{'receiver_puuid': '35a2368e-586f-53ec-8ee8-ea9ebdca7d6f',
#         'receiver_display_name': 'TADALA#TADAL',
#         'receiver_team': 'Blue',
#         'bodyshots': 2,
#         'damage': 60,
#         'headshots': 0,
#         'legshots': 0}],
#       'damage': 60,
#       'bodyshots': 2,
#       'headshots': 0,
#       'legshots': 0,
#       'kill_events': [],
#       'kills': 0,
#       'score': 60,
#       'economy': {'loadout_value': 900,
#        'weapon': {'id': '1BAA85B4-4C70-1284-64BB-6481DFC3BB4E',
#         'name': 'Ghost',
#         'assets': {'display_icon': 'https://media.valorant-api.com/weapons/1baa85b4-4c70-1284-64bb-6481dfc3bb4e/displayicon.png',
#          'killfeed_icon': 'https://media.valorant-api.com/weapons/1baa85b4-4c70-1284-64bb-6481dfc3bb4e/killstreamicon.png'}},
#        'armor': {'id': None, 'name': None, 'assets': {'display_icon': None}},
#        'remaining': 50,
#        'spent': 750},
#       'was_afk': False,
#       'was_penalized': False,
#       'stayed_in_spawn': False},
#      {'ability_casts': {'c_casts': None,
#        'q_casts': None,
#        'e_cast': None,
#        'x_cast': None},
#       'player_puuid': '624fadb6-52f7-555a-b5d7-f9b3c3a48811',
#       'player_display_name': 'Victor#01508',
#       'player_team': 'Red',
#       'damage_events': [],
#       'damage': 0,
#       'bodyshots': 0,
#       'headshots': 0,
#       'legshots': 0,
#       'kill_events': [],
#       'kills': 0,
#       'score': 0,
#       'economy': {'loadout_value': 650,
#        'weapon': {'id': '1BAA85B4-4C70-1284-64BB-6481DFC3BB4E',
#         'name': 'Ghost',
#         'assets': {'display_icon': 'https://media.valorant-api.com/weapons/1baa85b4-4c70-1284-64bb-6481dfc3bb4e/displayicon.png',
#          'killfeed_icon': 'https://media.valorant-api.com/weapons/1baa85b4-4c70-1284-64bb-6481dfc3bb4e/killstreamicon.png'}},
#        'armor': {'id': None, 'name': None, 'assets': {'display_icon': None}},
#        'remaining': 300,
#        'spent': 500},
#       'was_afk': False,
#       'was_penalized': False,
#       'stayed_in_spawn': False},
#      {'ability_casts': {'c_casts': None,
#        'q_casts': None,
#        'e_cast': None,
#        'x_cast': None},
#       'player_puuid': '6c241ab0-1c2f-5d5b-8908-4e809df8f6ca',
#       'player_display_name': 'mBirth#BR1',
#       'player_team': 'Blue',
#       'damage_events': [{'receiver_puuid': '55e10892-343a-52e1-a697-6d7c61ba6b01',
#         'receiver_display_name': 'SakurajimaSenpai#Virge',
#         'receiver_team': 'Red',
#         'bodyshots': 0,
#         'damage': 66,
#         'headshots': 1,
#         'legshots': 0},
#        {'receiver_puuid': 'c8b9ccaf-b781-58b9-b917-95a5599b02e1',
#         'receiver_display_name': 'CdB Lula2023#9351',
#         'receiver_team': 'Red',
#         'bodyshots': 1,
#         'damage': 26,
#         'headshots': 0,
#         'legshots': 0}],
#       'damage': 92,
#       'bodyshots': 1,
#       'headshots': 1,
#       'legshots': 0,
#       'kill_events': [{'kill_time_in_round': 28002,
#         'kill_time_in_match': 100027,
#         'killer_puuid': '6c241ab0-1c2f-5d5b-8908-4e809df8f6ca',
#         'killer_display_name': 'mBirth#BR1',
#         'killer_team': 'Blue',
#         'victim_puuid': '55e10892-343a-52e1-a697-6d7c61ba6b01',
#         'victim_display_name': 'SakurajimaSenpai#Virge',
#         'victim_team': 'Red',
#         'victim_death_location': {'x': -8256, 'y': 4357},
#         'damage_weapon_id': '29A0CFAB-485B-F5D5-779A-B59F85E204A8',
#         'damage_weapon_name': 'Classic',
#         'damage_weapon_assets': {'display_icon': 'https://media.valorant-api.com/weapons/29a0cfab-485b-f5d5-779a-b59f85e204a8/displayicon.png',
#          'killfeed_icon': 'https://media.valorant-api.com/weapons/29a0cfab-485b-f5d5-779a-b59f85e204a8/killstreamicon.png'},
#         'secondary_fire_mode': False,
#         'player_locations_on_kill': [{'player_puuid': '624fadb6-52f7-555a-b5d7-f9b3c3a48811',
#           'player_display_name': 'Victor#01508',
#           'player_team': 'Red',
#           'location': {'x': -6816, 'y': 3125},
#           'view_radians': 2.4490056},
#          {'player_puuid': '6c241ab0-1c2f-5d5b-8908-4e809df8f6ca',
#           'player_display_name': 'mBirth#BR1',
#           'player_team': 'Blue',
#           'location': {'x': -4942, 'y': 3786},
#           'view_radians': 2.9765928},
#          {'player_puuid': '35a2368e-586f-53ec-8ee8-ea9ebdca7d6f',
#           'player_display_name': 'TADALA#TADAL',
#           'player_team': 'Blue',
#           'location': {'x': -5563, 'y': 3872},
#           'view_radians': 4.0993657},
#          {'player_puuid': 'f2f7c867-27ba-5291-a23c-bbdcfc079e76',
#           'player_display_name': 'viikset#BR1',
#           'player_team': 'Blue',
#           'location': {'x': -4892, 'y': 3577},
#           'view_radians': 2.9124525},
#          {'player_puuid': 'b2310858-1741-5d6f-8499-cb1f85bd182a',
#           'player_display_name': 'Kubata#4881',
#           'player_team': 'Blue',
#           'location': {'x': -6394, 'y': 4337},
#           'view_radians': 3.6117575},
#          {'player_puuid': '7e7baebf-2828-5788-8846-70972f13c6bd',
#           'player_display_name': 'homem rocha#2376',
#           'player_team': 'Red',
#           'location': {'x': -7298, 'y': -653},
#           'view_radians': 6.038047},
#          {'player_puuid': '6a91f483-ea58-54de-bf9b-de6ea23ba5e6',
#           'player_display_name': 'Adam Barlyn#BR1',
#           'player_team': 'Red',
#           'location': {'x': -7391, 'y': 2457},
#           'view_radians': 1.4027202},
#          {'player_puuid': 'c8b9ccaf-b781-58b9-b917-95a5599b02e1',
#           'player_display_name': 'CdB Lula2023#9351',
#           'player_team': 'Red',
#           'location': {'x': -7267, 'y': 2707},
#           'view_radians': 1.7109638},
#          {'player_puuid': '2c51a2e4-0dcf-53f5-ae85-cd4d7d79f663',
#           'player_display_name': 'DIGAOTJS#BR1',
#           'player_team': 'Blue',
#           'location': {'x': 318, 'y': 1747},
#           'view_radians': 3.1891465}],
#         'assistants': []}],
#       'kills': 1,
#       'score': 232,
#       'economy': {'loadout_value': 600,
#        'weapon': {'id': '29A0CFAB-485B-F5D5-779A-B59F85E204A8',
#         'name': 'Classic',
#         'assets': {'display_icon': 'https://media.valorant-api.com/weapons/29a0cfab-485b-f5d5-779a-b59f85e204a8/displayicon.png',
#          'killfeed_icon': 'https://media.valorant-api.com/weapons/29a0cfab-485b-f5d5-779a-b59f85e204a8/killstreamicon.png'}},
#        'armor': {'id': '4DEC83D5-4902-9AB3-BED6-A7A390761157',
#         'name': 'Light Shields',
#         'assets': {'display_icon': 'https://media.valorant-api.com/gear/4dec83d5-4902-9ab3-bed6-a7a390761157/displayicon.png'}},
#        'remaining': 0,
#        'spent': 800},
#       'was_afk': False,
#       'was_penalized': False,
#       'stayed_in_spawn': False},
#      {'ability_casts': {'c_casts': None,
#        'q_casts': None,
#        'e_cast': None,
#        'x_cast': None},
#       'player_puuid': '35a2368e-586f-53ec-8ee8-ea9ebdca7d6f',
#       'player_display_name': 'TADALA#TADAL',
#       'player_team': 'Blue',
#       'damage_events': [{'receiver_puuid': '624fadb6-52f7-555a-b5d7-f9b3c3a48811',
#         'receiver_display_name': 'Victor#01508',
#         'receiver_team': 'Red',
#         'bodyshots': 1,
#         'damage': 30,
#         'headshots': 0,
#         'legshots': 0},
#        {'receiver_puuid': 'c8b9ccaf-b781-58b9-b917-95a5599b02e1',
#         'receiver_display_name': 'CdB Lula2023#9351',
#         'receiver_team': 'Red',
#         'bodyshots': 2,
#         'damage': 60,
#         'headshots': 0,
#         'legshots': 0}],
#       'damage': 90,
#       'bodyshots': 3,
#       'headshots': 0,
#       'legshots': 0,
#       'kill_events': [],
#       'kills': 0,
#       'score': 90,
# ...
#       'player_display_name': 'Victor#01508',
#       'player_team': 'Red',
#       'location': {'x': 2092, 'y': 2334},
#       'view_radians': 2.4738321},
#      {'player_puuid': '6a91f483-ea58-54de-bf9b-de6ea23ba5e6',
#       'player_display_name': 'Adam Barlyn#BR1',
#       'player_team': 'Red',
#       'location': {'x': 958, 'y': 4021},
#       'view_radians': 5.7704253}],
#     'assistants': [{'assistant_puuid': 'c8b9ccaf-b781-58b9-b917-95a5599b02e1',
#       'assistant_display_name': 'CdB Lula2023#9351',
#       'assistant_team': 'Red'},
#      {'assistant_puuid': '6a91f483-ea58-54de-bf9b-de6ea23ba5e6',
#       'assistant_display_name': 'Adam Barlyn#BR1',
#       'assistant_team': 'Red'}]},
#    {'kill_time_in_round': 11793,
#     'kill_time_in_match': 2029525,
#     'round': 19,
#     'killer_puuid': 'c8b9ccaf-b781-58b9-b917-95a5599b02e1',
#     'killer_display_name': 'CdB Lula2023#9351',
#     'killer_team': 'Red',
#     'victim_puuid': 'b2310858-1741-5d6f-8499-cb1f85bd182a',
#     'victim_display_name': 'Kubata#4881',
#     'victim_team': 'Blue',
#     'victim_death_location': {'x': -4577, 'y': -1502},
#     'damage_weapon_id': '63E6C2B6-4A8E-869C-3D4C-E38355226584',
#     'damage_weapon_name': 'Odin',
#     'damage_weapon_assets': {'display_icon': 'https://media.valorant-api.com/weapons/63e6c2b6-4a8e-869c-3d4c-e38355226584/displayicon.png',
#      'killfeed_icon': 'https://media.valorant-api.com/weapons/63e6c2b6-4a8e-869c-3d4c-e38355226584/killstreamicon.png'},
#     'secondary_fire_mode': True,
#     'player_locations_on_kill': [{'player_puuid': '55e10892-343a-52e1-a697-6d7c61ba6b01',
#       'player_display_name': 'SakurajimaSenpai#Virge',
#       'player_team': 'Red',
#       'location': {'x': -4992, 'y': -559},
#       'view_radians': 3.9842844},
#      {'player_puuid': '624fadb6-52f7-555a-b5d7-f9b3c3a48811',
#       'player_display_name': 'Victor#01508',
#       'player_team': 'Red',
#       'location': {'x': 391, 'y': 148},
#       'view_radians': 3.5565329},
#      {'player_puuid': '6c241ab0-1c2f-5d5b-8908-4e809df8f6ca',
#       'player_display_name': 'mBirth#BR1',
#       'player_team': 'Blue',
#       'location': {'x': -1750, 'y': -1994},
#       'view_radians': 0.18235435},
#      {'player_puuid': '35a2368e-586f-53ec-8ee8-ea9ebdca7d6f',
#       'player_display_name': 'TADALA#TADAL',
#       'player_team': 'Blue',
#       'location': {'x': -2097, 'y': -845},
#       'view_radians': 0.08195385},
#      {'player_puuid': 'f2f7c867-27ba-5291-a23c-bbdcfc079e76',
#       'player_display_name': 'viikset#BR1',
#       'player_team': 'Blue',
#       'location': {'x': -5230, 'y': -1090},
#       'view_radians': 1.59891},
#      {'player_puuid': '7e7baebf-2828-5788-8846-70972f13c6bd',
#       'player_display_name': 'homem rocha#2376',
#       'player_team': 'Red',
#       'location': {'x': -4299, 'y': 2969},
#       'view_radians': 4.6482487},
#      {'player_puuid': '6a91f483-ea58-54de-bf9b-de6ea23ba5e6',
#       'player_display_name': 'Adam Barlyn#BR1',
#       'player_team': 'Red',
#       'location': {'x': -8257, 'y': 3263},
#       'view_radians': 6.181655},
#      {'player_puuid': 'c8b9ccaf-b781-58b9-b917-95a5599b02e1',
#       'player_display_name': 'CdB Lula2023#9351',
#       'player_team': 'Red',
#       'location': {'x': -1798, 'y': 1594},
#       'view_radians': 3.9595876},
#      {'player_puuid': '2c51a2e4-0dcf-53f5-ae85-cd4d7d79f663',
#       'player_display_name': 'DIGAOTJS#BR1',
#       'player_team': 'Blue',
#       'location': {'x': -2550, 'y': 403},
#       'view_radians': 2.010184}],
#     'assistants': []},
#    {'kill_time_in_round': 17062,
#     'kill_time_in_match': 2034794,
#     'round': 19,
#     'killer_puuid': '55e10892-343a-52e1-a697-6d7c61ba6b01',
#     'killer_display_name': 'SakurajimaSenpai#Virge',
#     'killer_team': 'Red',
#     'victim_puuid': 'f2f7c867-27ba-5291-a23c-bbdcfc079e76',
#     'victim_display_name': 'viikset#BR1',
#     'victim_team': 'Blue',
#     'victim_death_location': {'x': -4967, 'y': -817},
#     'damage_weapon_id': '462080D1-4035-2937-7C09-27AA2A5C27A7',
#     'damage_weapon_name': 'Spectre',
#     'damage_weapon_assets': {'display_icon': 'https://media.valorant-api.com/weapons/462080d1-4035-2937-7c09-27aa2a5c27a7/displayicon.png',
#      'killfeed_icon': 'https://media.valorant-api.com/weapons/462080d1-4035-2937-7c09-27aa2a5c27a7/killstreamicon.png'},
#     'secondary_fire_mode': False,
#     'player_locations_on_kill': [{'player_puuid': '55e10892-343a-52e1-a697-6d7c61ba6b01',
#       'player_display_name': 'SakurajimaSenpai#Virge',
#       'player_team': 'Red',
#       'location': {'x': -5195, 'y': 252},
#       'view_radians': 4.9173675},
#      {'player_puuid': '624fadb6-52f7-555a-b5d7-f9b3c3a48811',
#       'player_display_name': 'Victor#01508',
#       'player_team': 'Red',
#       'location': {'x': 232, 'y': -110},
#       'view_radians': 3.8797162},
#      {'player_puuid': '6c241ab0-1c2f-5d5b-8908-4e809df8f6ca',
#       'player_display_name': 'mBirth#BR1',
#       'player_team': 'Blue',
#       'location': {'x': -1427, 'y': -1885},
#       'view_radians': 3.3023448},
#      {'player_puuid': '35a2368e-586f-53ec-8ee8-ea9ebdca7d6f',
#       'player_display_name': 'TADALA#TADAL',
#       'player_team': 'Blue',
#       'location': {'x': -2770, 'y': -2188},
#       'view_radians': 2.8755426},
#      {'player_puuid': '7e7baebf-2828-5788-8846-70972f13c6bd',
#       'player_display_name': 'homem rocha#2376',
#       'player_team': 'Red',
#       'location': {'x': -4286, 'y': 3164},
#       'view_radians': 4.6482487},
#      {'player_puuid': '6a91f483-ea58-54de-bf9b-de6ea23ba5e6',
#       'player_display_name': 'Adam Barlyn#BR1',
#       'player_team': 'Red',
#       'location': {'x': -8257, 'y': 3263},
#       'view_radians': 0.019730946},
#      {'player_puuid': 'c8b9ccaf-b781-58b9-b917-95a5599b02e1',
#       'player_display_name': 'CdB Lula2023#9351',
#       'player_team': 'Red',
#       'location': {'x': -2643, 'y': 806},
#       'view_radians': 3.8614128},
#      {'player_puuid': '2c51a2e4-0dcf-53f5-ae85-cd4d7d79f663',
#       'player_display_name': 'DIGAOTJS#BR1',
#       'player_team': 'Blue',
#       'location': {'x': -2207, 'y': 446},
#       'view_radians': 2.1360686}],
#     'assistants': []},
#    {'kill_time_in_round': 19271,
#     'kill_time_in_match': 2037003,
#     'round': 19,
#     'killer_puuid': '2c51a2e4-0dcf-53f5-ae85-cd4d7d79f663',
#     'killer_display_name': 'DIGAOTJS#BR1',
#     'killer_team': 'Blue',
#     'victim_puuid': 'c8b9ccaf-b781-58b9-b917-95a5599b02e1',
#     'victim_display_name': 'CdB Lula2023#9351',
#     'victim_team': 'Red',
#     'victim_death_location': {'x': -2264, 'y': -93},
#     'damage_weapon_id': '9C82E19D-4575-0200-1A81-3EACF00CF872',
#     'damage_weapon_name': 'Vandal',
#     'damage_weapon_assets': {'display_icon': 'https://media.valorant-api.com/weapons/9c82e19d-4575-0200-1a81-3eacf00cf872/displayicon.png',
#      'killfeed_icon': 'https://media.valorant-api.com/weapons/9c82e19d-4575-0200-1a81-3eacf00cf872/killstreamicon.png'},
#     'secondary_fire_mode': False,
#     'player_locations_on_kill': [{'player_puuid': '55e10892-343a-52e1-a697-6d7c61ba6b01',
#       'player_display_name': 'SakurajimaSenpai#Virge',
#       'player_team': 'Red',
#       'location': {'x': -742, 'y': 1092},
#       'view_radians': 2.8254957},
#      {'player_puuid': '624fadb6-52f7-555a-b5d7-f9b3c3a48811',
#       'player_display_name': 'Victor#01508',
#       'player_team': 'Red',
#       'location': {'x': -32, 'y': -689},
#       'view_radians': 3.6250308},
#      {'player_puuid': '6c241ab0-1c2f-5d5b-8908-4e809df8f6ca',
#       'player_display_name': 'mBirth#BR1',
#       'player_team': 'Blue',
#       'location': {'x': -1425, 'y': -1785},
#       'view_radians': 1.4097677},
#      {'player_puuid': '35a2368e-586f-53ec-8ee8-ea9ebdca7d6f',
#       'player_display_name': 'TADALA#TADAL',
#       'player_team': 'Blue',
#       'location': {'x': -2824, 'y': -1863},
#       'view_radians': 2.967005},
#      {'player_puuid': '7e7baebf-2828-5788-8846-70972f13c6bd',
#       'player_display_name': 'homem rocha#2376',
#       'player_team': 'Red',
#       'location': {'x': -4286, 'y': 3164},
#       'view_radians': 4.6482487},
#      {'player_puuid': '6a91f483-ea58-54de-bf9b-de6ea23ba5e6',
#       'player_display_name': 'Adam Barlyn#BR1',
#       'player_team': 'Red',
#       'location': {'x': -8257, 'y': 3263},
#       'view_radians': 6.184148},
#      {'player_puuid': '2c51a2e4-0dcf-53f5-ae85-cd4d7d79f663',
#       'player_display_name': 'DIGAOTJS#BR1',
#       'player_team': 'Blue',
#       'location': {'x': -2207, 'y': 364},
#       'view_radians': 4.5272555}],
#     'assistants': []},
#    {'kill_time_in_round': 21206,
#     'kill_time_in_match': 2038938,
#     'round': 19,
#     'killer_puuid': '624fadb6-52f7-555a-b5d7-f9b3c3a48811',
#     'killer_display_name': 'Victor#01508',
#     'killer_team': 'Red',
#     'victim_puuid': '6c241ab0-1c2f-5d5b-8908-4e809df8f6ca',
#     'victim_display_name': 'mBirth#BR1',
#     'victim_team': 'Blue',
#     'victim_death_location': {'x': -1168, 'y': -1270},
#     'damage_weapon_id': '9C82E19D-4575-0200-1A81-3EACF00CF872',
#     'damage_weapon_name': 'Vandal',
#     'damage_weapon_assets': {'display_icon': 'https://media.valorant-api.com/weapons/9c82e19d-4575-0200-1a81-3eacf00cf872/displayicon.png',
#      'killfeed_icon': 'https://media.valorant-api.com/weapons/9c82e19d-4575-0200-1a81-3eacf00cf872/killstreamicon.png'},
#     'secondary_fire_mode': False,
#     'player_locations_on_kill': [{'player_puuid': '55e10892-343a-52e1-a697-6d7c61ba6b01',
#       'player_display_name': 'SakurajimaSenpai#Virge',
#       'player_team': 'Red',
#       'location': {'x': -1820, 'y': 1092},
#       'view_radians': 3.322777},
#      {'player_puuid': '624fadb6-52f7-555a-b5d7-f9b3c3a48811',
#       'player_display_name': 'Victor#01508',
#       'player_team': 'Red',
#       'location': {'x': -416, 'y': -1104},
#       'view_radians': 3.374759},
#      {'player_puuid': '35a2368e-586f-53ec-8ee8-ea9ebdca7d6f',
#       'player_display_name': 'TADALA#TADAL',
#       'player_team': 'Blue',
#       'location': {'x': -2986, 'y': -1837},
#       'view_radians': 2.9422617},
#      {'player_puuid': '7e7baebf-2828-5788-8846-70972f13c6bd',
#       'player_display_name': 'homem rocha#2376',
#       'player_team': 'Red',
#       'location': {'x': -4322, 'y': 2621},
#       'view_radians': 5.3969064},
#      {'player_puuid': '6a91f483-ea58-54de-bf9b-de6ea23ba5e6',
#       'player_display_name': 'Adam Barlyn#BR1',
#       'player_team': 'Red',
#       'location': {'x': -8257, 'y': 3263},
#       'view_radians': 6.1791615},
#      {'player_puuid': '2c51a2e4-0dcf-53f5-ae85-cd4d7d79f663',
#       'player_display_name': 'DIGAOTJS#BR1',
#       'player_team': 'Blue',
#       'location': {'x': -2281, 'y': 6},
#       'view_radians': 1.7925532}],
#     'assistants': []},
#    {'kill_time_in_round': 27594,
#     'kill_time_in_match': 2045326,
#     'round': 19,
#     'killer_puuid': '55e10892-343a-52e1-a697-6d7c61ba6b01',
#     'killer_display_name': 'SakurajimaSenpai#Virge',
#     'killer_team': 'Red',
#     'victim_puuid': '2c51a2e4-0dcf-53f5-ae85-cd4d7d79f663',
#     'victim_display_name': 'DIGAOTJS#BR1',
#     'victim_team': 'Blue',
#     'victim_death_location': {'x': -2940, 'y': 225},
#     'damage_weapon_id': '462080D1-4035-2937-7C09-27AA2A5C27A7',
#     'damage_weapon_name': 'Spectre',
#     'damage_weapon_assets': {'display_icon': 'https://media.valorant-api.com/weapons/462080d1-4035-2937-7c09-27aa2a5c27a7/displayicon.png',
#      'killfeed_icon': 'https://media.valorant-api.com/weapons/462080d1-4035-2937-7c09-27aa2a5c27a7/killstreamicon.png'},
#     'secondary_fire_mode': False,
#     'player_locations_on_kill': [{'player_puuid': '55e10892-343a-52e1-a697-6d7c61ba6b01',
#       'player_display_name': 'SakurajimaSenpai#Virge',
#       'player_team': 'Red',
#       'location': {'x': -1989, 'y': 1442},
#       'view_radians': 4.0316854},
#      {'player_puuid': '624fadb6-52f7-555a-b5d7-f9b3c3a48811',
#       'player_display_name': 'Victor#01508',
#       'player_team': 'Red',
#       'location': {'x': -1316, 'y': -1770},
#       'view_radians': 3.1294167},
#      {'player_puuid': '35a2368e-586f-53ec-8ee8-ea9ebdca7d6f',
#       'player_display_name': 'TADALA#TADAL',
#       'player_team': 'Blue',
#       'location': {'x': -2107, 'y': -1174},
#       'view_radians': 5.1620355},
#      {'player_puuid': '7e7baebf-2828-5788-8846-70972f13c6bd',
#       'player_display_name': 'homem rocha#2376',
#       'player_team': 'Red',
#       'location': {'x': -4239, 'y': 2323},
#       'view_radians': 5.7008467},
#      {'player_puuid': '6a91f483-ea58-54de-bf9b-de6ea23ba5e6',
#       'player_display_name': 'Adam Barlyn#BR1',
#       'player_team': 'Red',
#       'location': {'x': -8257, 'y': 3263},
#       'view_radians': 6.1791615}],
#     'assistants': [{'assistant_puuid': 'c8b9ccaf-b781-58b9-b917-95a5599b02e1',
#       'assistant_display_name': 'CdB Lula2023#9351',
#       'assistant_team': 'Red'}]},
#    {'kill_time_in_round': 30206,
#     'kill_time_in_match': 2047938,
#     'round': 19,
#     'killer_puuid': '35a2368e-586f-53ec-8ee8-ea9ebdca7d6f',
#     'killer_display_name': 'TADALA#TADAL',
#     'killer_team': 'Blue',
#     'victim_puuid': '624fadb6-52f7-555a-b5d7-f9b3c3a48811',
#     'victim_display_name': 'Victor#01508',
#     'victim_team': 'Red',
#     'victim_death_location': {'x': -2035, 'y': -2153},
#     'damage_weapon_id': '55D8A0F4-4274-CA67-FE2C-06AB45EFDF58',
#     'damage_weapon_name': 'Ares',
#     'damage_weapon_assets': {'display_icon': 'https://media.valorant-api.com/weapons/55d8a0f4-4274-ca67-fe2c-06ab45efdf58/displayicon.png',
#      'killfeed_icon': 'https://media.valorant-api.com/weapons/55d8a0f4-4274-ca67-fe2c-06ab45efdf58/killstreamicon.png'},
#     'secondary_fire_mode': False,
#     'player_locations_on_kill': [{'player_puuid': '55e10892-343a-52e1-a697-6d7c61ba6b01',
#       'player_display_name': 'SakurajimaSenpai#Virge',
#       'player_team': 'Red',
#       'location': {'x': -1954, 'y': 1478},
#       'view_radians': 3.9846942},
#      {'player_puuid': '35a2368e-586f-53ec-8ee8-ea9ebdca7d6f',
#       'player_display_name': 'TADALA#TADAL',
#       'player_team': 'Blue',
#       'location': {'x': -1901, 'y': -694},
#       'view_radians': 4.6100917},
#      {'player_puuid': '7e7baebf-2828-5788-8846-70972f13c6bd',
#       'player_display_name': 'homem rocha#2376',
#       'player_team': 'Red',
#       'location': {'x': -3407, 'y': 1741},
#       'view_radians': 5.7522364},
#      {'player_puuid': '6a91f483-ea58-54de-bf9b-de6ea23ba5e6',
#       'player_display_name': 'Adam Barlyn#BR1',
#       'player_team': 'Red',
#       'location': {'x': -7871, 'y': 3288},
#       'view_radians': 4.797621}],
#     'assistants': [{'assistant_puuid': '6c241ab0-1c2f-5d5b-8908-4e809df8f6ca',
#       'assistant_display_name': 'mBirth#BR1',
#       'assistant_team': 'Blue'}]},
#    {'kill_time_in_round': 44152,
#     'kill_time_in_match': 2061884,
#     'round': 19,
#     'killer_puuid': '55e10892-343a-52e1-a697-6d7c61ba6b01',
#     'killer_display_name': 'SakurajimaSenpai#Virge',
#     'killer_team': 'Red',
#     'victim_puuid': '35a2368e-586f-53ec-8ee8-ea9ebdca7d6f',
#     'victim_display_name': 'TADALA#TADAL',
#     'victim_team': 'Blue',
#     'victim_death_location': {'x': -1522, 'y': -1924},
#     'damage_weapon_id': '9C82E19D-4575-0200-1A81-3EACF00CF872',
#     'damage_weapon_name': 'Vandal',
#     'damage_weapon_assets': {'display_icon': 'https://media.valorant-api.com/weapons/9c82e19d-4575-0200-1a81-3eacf00cf872/displayicon.png',
#      'killfeed_icon': 'https://media.valorant-api.com/weapons/9c82e19d-4575-0200-1a81-3eacf00cf872/killstreamicon.png'},
#     'secondary_fire_mode': False,
#     'player_locations_on_kill': [{'player_puuid': '55e10892-343a-52e1-a697-6d7c61ba6b01',
#       'player_display_name': 'SakurajimaSenpai#Virge',
#       'player_team': 'Red',
#       'location': {'x': -3261, 'y': -3874},
#       'view_radians': 0.83544344},
#      {'player_puuid': '7e7baebf-2828-5788-8846-70972f13c6bd',
#       'player_display_name': 'homem rocha#2376',
#       'player_team': 'Red',
#       'location': {'x': -3597, 'y': -1115},
#       'view_radians': 4.7165117},
#      {'player_puuid': '6a91f483-ea58-54de-bf9b-de6ea23ba5e6',
#       'player_display_name': 'Adam Barlyn#BR1',
#       'player_team': 'Red',
#       'location': {'x': -5143, 'y': 48},
#       'view_radians': 4.49077}],
#     'assistants': []}]}}

# %%
for i in response.json()['data']['players']['all_players']:
    print(i['name'], i['puuid'])
# Out:
# SakurajimaSenpai 55e10892-343a-52e1-a697-6d7c61ba6b01
# TADALA 35a2368e-586f-53ec-8ee8-ea9ebdca7d6f
# Adam Barlyn 6a91f483-ea58-54de-bf9b-de6ea23ba5e6
# Kubata b2310858-1741-5d6f-8499-cb1f85bd182a
# DIGAOTJS 2c51a2e4-0dcf-53f5-ae85-cd4d7d79f663
# viikset f2f7c867-27ba-5291-a23c-bbdcfc079e76
# Victor 624fadb6-52f7-555a-b5d7-f9b3c3a48811
# homem rocha 7e7baebf-2828-5788-8846-70972f13c6bd
# CdB Lula2023 c8b9ccaf-b781-58b9-b917-95a5599b02e1
# mBirth 6c241ab0-1c2f-5d5b-8908-4e809df8f6ca
